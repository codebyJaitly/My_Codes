# %%
import pandas as pd
import os
from tkinter import Tk, filedialog
from openpyxl import load_workbook

def select_directory():
    """ Open a dialog to select a directory. """
    root = Tk()
    root.withdraw()  # Hide the main window
    folder_selected = filedialog.askdirectory()
    root.destroy()
    return folder_selected

def select_file(title="Select file"):
    """ Open a dialog to select a file. """
    root = Tk()
    root.withdraw()
    file_path = filedialog.askopenfilename(title=title)
    root.destroy()
    return file_path

def load_data_from_excel(folder_path):
    """ Load data from the first Excel file found in the provided directory. """
    for file in os.listdir(folder_path):
        if file.endswith('.xlsx'):
            return pd.read_excel(os.path.join(folder_path, file))
    raise FileNotFoundError("No Excel file found in the directory.")

def load_filter_list(file_path):
    """ Load list of items to filter from an Excel file and extract the header as column name. """
    wb = load_workbook(file_path)
    ws = wb.active
    filter_list = pd.read_excel(file_path, header=None)[0].tolist()
    column_name = ws.iter_rows(min_row=1, max_row=1, values_only=True).__next__()[0]
    return filter_list, column_name

def filter_and_save_data(data, filter_list, column_name, output_folder):
    """ Filter and save data based on each item in the filter list and specified column name. """
    output_folder = os.path.join(output_folder, "output")
    os.makedirs(output_folder, exist_ok=True)  # Create output folder if it doesn't exist

    for item in filter_list:
        filtered_data = data[data[column_name].str.contains(item, na=False)]
        output_path = os.path.join(output_folder, f"{item}.xlsx")
        filtered_data.to_excel(output_path, index=False)
        print(f"Data filtered by {item} has been saved to {output_path}")

def main():
    print("Select the directory containing your main data Excel file:")
    data_folder = select_directory()
    print("Select the Excel file with the filter list:")
    filter_file_path = select_file("Select the filter list file")

    try:
        data = load_data_from_excel(data_folder)
        filter_list, column_name = load_filter_list(filter_file_path)
        print("Processing and saving filtered files...")
        filter_and_save_data(data, filter_list, column_name, data_folder)
        print("All files have been processed and saved successfully.")
    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    main()
# Out:
# Select the directory containing your main data Excel file:
# Select the Excel file with the filter list:
# Processing and saving filtered files...
# Data filtered by Symbol has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\Symbol.xlsx
# Data filtered by TATASTEEL has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\TATASTEEL.xlsx
# Data filtered by BPCL has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\BPCL.xlsx
# Data filtered by AWHCL has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\AWHCL.xlsx
# Data filtered by NAUKRI has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\NAUKRI.xlsx
# Data filtered by JUBLINDS has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\JUBLINDS.xlsx
# Data filtered by ZOMATO has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\ZOMATO.xlsx
# Data filtered by TATASTLLP has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\TATASTLLP.xlsx
# Data filtered by ISEC has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\ISEC.xlsx
# Data filtered by AARTIDRUGS has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\AARTIDRUGS.xlsx
# Data filtered by ALKEM has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\ALKEM.xlsx
# Data filtered by AJANTPHARM has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\AJANTPHARM.xlsx
# Data filtered by OFSS has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\OFSS.xlsx
# Data filtered by LALPATHLAB has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\LALPATHLAB.xlsx
# Data filtered by SUNTV has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\SUNTV.xlsx
# Data filtered by IBULHSGFIN has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\IBULHSGFIN.xlsx
# Data filtered by GICRE has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\GICRE.xlsx
# Data filtered by GOODYEAR has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\GOODYEAR.xlsx
# Data filtered by HCLTECH has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\HCLTECH.xlsx
# Data filtered by TATAPOWER has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\TATAPOWER.xlsx
# Data filtered by INFY has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\INFY.xlsx
# Data filtered by ADANIPORTS has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\ADANIPORTS.xlsx
# Data filtered by HDFCAMC has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\HDFCAMC.xlsx
# Data filtered by LTTS has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\LTTS.xlsx
# Data filtered by LTI has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\LTI.xlsx
# Data filtered by BAJFINANCE has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\BAJFINANCE.xlsx
# Data filtered by VAIBHAVGBL has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\VAIBHAVGBL.xlsx
# Data filtered by IEX has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\IEX.xlsx
# Data filtered by COALINDIA has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\COALINDIA.xlsx
# Data filtered by DEEPAKNTR has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\DEEPAKNTR.xlsx
# Data filtered by APOLLOHOSP has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\APOLLOHOSP.xlsx
# Data filtered by DEEPAKNI has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\DEEPAKNI.xlsx
# Data filtered by HATHWAY has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\HATHWAY.xlsx
# Data filtered by DIVISLAB has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\DIVISLAB.xlsx
# Data filtered by JPPOWER has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\JPPOWER.xlsx
# Data filtered by BAJAJHIND has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\BAJAJHIND.xlsx
# Data filtered by ADANIPOWER has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\ADANIPOWER.xlsx
# Data filtered by LATIMMETAL has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\LATIMMETAL.xlsx
# Data filtered by VOLTAS has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\VOLTAS.xlsx
# Data filtered by HAVELLS has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\HAVELLS.xlsx
# Data filtered by BCG has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\BCG.xlsx
# Data filtered by HDFCLIFE has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\HDFCLIFE.xlsx
# Data filtered by EMAMILTD has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\EMAMILTD.xlsx
# Data filtered by CDSL has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\CDSL.xlsx
# Data filtered by TRIL has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\TRIL.xlsx
# Data filtered by RELIANCE has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\RELIANCE.xlsx
# Data filtered by ICICIPRULI has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\ICICIPRULI.xlsx
# Data filtered by PATANJALI has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\PATANJALI.xlsx
# Data filtered by MPHASIS has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\MPHASIS.xlsx
# Data filtered by TVTODAY has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\TVTODAY.xlsx
# Data filtered by MANYAVAR has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\MANYAVAR.xlsx
# Data filtered by IRCTC has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\IRCTC.xlsx
# Data filtered by SOUTHBANK has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\SOUTHBANK.xlsx
# Data filtered by ATGL has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\ATGL.xlsx
# Data filtered by TIDEWATER has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\TIDEWATER.xlsx
# Data filtered by EIDPARRY has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\EIDPARRY.xlsx
# Data filtered by PAGEIND has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\PAGEIND.xlsx
# Data filtered by DELTACORP has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\DELTACORP.xlsx
# Data filtered by SRF has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\SRF.xlsx
# Data filtered by FLUOROCHEM has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\FLUOROCHEM.xlsx
# Data filtered by RPOWER has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\RPOWER.xlsx
# Data filtered by PNB has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\PNB.xlsx
# Data filtered by BAJAJFINSV has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\BAJAJFINSV.xlsx
# Data filtered by BANKBARODA has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\BANKBARODA.xlsx
# Data filtered by AMARAJABAT has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\AMARAJABAT.xlsx
# Data filtered by EXIDEIND has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\EXIDEIND.xlsx
# Data filtered by CEATLTD has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\CEATLTD.xlsx
# Data filtered by 5PAISA has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\5PAISA.xlsx
# Data filtered by LT has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\LT.xlsx
# Data filtered by GAIL has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\GAIL.xlsx
# Data filtered by BHEL has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\BHEL.xlsx
# Data filtered by VEDL has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\VEDL.xlsx
# Data filtered by MMTC has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\MMTC.xlsx
# Data filtered by RVNL has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\RVNL.xlsx
# Data filtered by ATULAUTO has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\ATULAUTO.xlsx
# Data filtered by RAJESHEXPO has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\RAJESHEXPO.xlsx
# Data filtered by RENUKA has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\RENUKA.xlsx
# Data filtered by MAWANASUG has been saved to C:/Users/dell/Desktop/Gaurav HSBC/Slicer/Data\output\MAWANASUG.xlsx
# All files have been processed and saved successfully.
